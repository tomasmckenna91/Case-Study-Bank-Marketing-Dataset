# %% [markdown]
# ## EDA on Banking Data set

# %% [markdown]
# About Dataset
# Context
#
# Find the best strategies to improve for the next marketing campaign. How can the financial institution have a greater effectiveness for future marketing campaigns? In order to answer this, we have to analyze the last marketing campaign the bank performed and identify the patterns that will help us find conclusions in order to develop future strategies.
# Source
#
# [Moro et al., 2014] S. Moro, P. Cortez and P. Rita. A Data-Driven Approach to Predict the Success of Bank Telemarketing. Decision Support Systems, Elsevier, 62:22-31, June 2014

# %% [markdown]
# Imports

# %%
# !pip install sweetviz
# !pip install lazypredict

# %%
# import sweetviz as sv
# import lazypredict as lz
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import os
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("bank.csv")

# %% [markdown]
# Introduction:
#
# Now that the dataset has been created following all imports. Lets check the information about the dataframe structure and check it has loaded correctly

# %%
df.shape
# Out:
# (11162, 17)

# %%
df.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11162 entries, 0 to 11161
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        11162 non-null  int64
#  1   job        11162 non-null  object
#  2   marital    11162 non-null  object
#  3   education  11162 non-null  object
#  4   default    11162 non-null  object
#  5   balance    11162 non-null  int64
#  6   housing    11162 non-null  object
#  7   loan       11162 non-null  object
#  8   contact    11162 non-null  object
#  9   day        11162 non-null  int64
#  10  month      11162 non-null  object
#  11  duration   11162 non-null  int64
#  12  campaign   11162 non-null  int64
#  13  pdays      11162 non-null  int64
#  14  previous   11162 non-null  int64
#  15  poutcome   11162 non-null  object
#  16  deposit    11162 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 1.4+ MB

# %%
# Describe numerical columns
df.describe()
# Out:
#                 age       balance           day      duration      campaign  \
# count  11162.000000  11162.000000  11162.000000  11162.000000  11162.000000
# mean      41.231948   1528.538524     15.658036    371.993818      2.508421
# std       11.913369   3225.413326      8.420740    347.128386      2.722077
# min       18.000000  -6847.000000      1.000000      2.000000      1.000000
# 25%       32.000000    122.000000      8.000000    138.000000      1.000000
# 50%       39.000000    550.000000     15.000000    255.000000      2.000000
# 75%       49.000000   1708.000000     22.000000    496.000000      3.000000
# max       95.000000  81204.000000     31.000000   3881.000000     63.000000
#
#               pdays      previous
# count  11162.000000  11162.000000
# mean      51.330407      0.832557
# std      108.758282      2.292007
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       20.750000      1.000000
# ...

# %% [markdown]
# Now we have an understanding of the numerical columns lets look at the categorical ones by finding the unique values

# %%
# find the unique values from categorical features
for col in df.select_dtypes(include='object').columns:
    print(col)
    print(df[col].unique())
# Out:
# job
# ['admin.' 'technician' 'services' 'management' 'retired' 'blue-collar'
#  'unemployed' 'entrepreneur' 'housemaid' 'unknown' 'self-employed'
#  'student']
# marital
# ['married' 'single' 'divorced']
# education
# ['secondary' 'tertiary' 'primary' 'unknown']
# default
# ['no' 'yes']
# housing
# ['yes' 'no']
# loan
# ['no' 'yes']
# contact
# ['unknown' 'cellular' 'telephone']
# month
# ['may' 'jun' 'jul' 'aug' 'oct' 'nov' 'dec' 'jan' 'feb' 'mar' 'apr' 'sep']
# poutcome
# ['unknown' 'other' 'failure' 'success']
# deposit
# ['yes' 'no']

# %%
# We will look to drop deposit for our categorical features
categorical_features = [feature for feature in df.columns if ((df[feature].dtypes=='O') & (feature not in ['deposit']))]
categorical_features
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'poutcome']

# %%
#check count based on categorical features
plt.figure(figsize=(15,80), facecolor='white')
plotnumber =1
for categorical_feature in categorical_features:
    ax = plt.subplot(12,3,plotnumber)
    sns.countplot(y=categorical_feature,data=df)
    plt.xlabel(categorical_feature)
    plt.title(categorical_feature)
    plotnumber+=1
plt.show()

# %% [markdown]
# Outcomes:
# No null values therefore data processing for this are not required
#
# Jobs are predominantly Management and Technician and Blue Collar whilst Housemaids are the least
#
# High number of married customers whilst divorced is low
#
# As majority of the default column is represented as no and therefore does not provide much information.
#
# Clients with Secondary Education level are represented most in the data.

# %% [markdown]
# Task 1 - Looking into the dataset in further detail.
#
# Select features to investigate further:
#
# *   Education
# *   Balance
# *   Age
# *   Job
#
# Process the data to gain information from figures:
#
#
# *   Remove outliers - Via Zscore or IQR

# %%
# Glance - Check visually Education Vs Balance
sns.set(rc={'figure.figsize': (15,10)})
sns.boxplot(data=df, x= 'education', y='balance');

# %%
# Calculate quantiles and IQR
Q1 = df['balance'].quantile(0.25)
Q3 = df['balance'].quantile(0.75)
IQR = Q3 - Q1

# Define upper and lower bounds for outliers
upper_bound = Q3 + 1.5 * IQR
lower_bound = Q1 - 1.5 * IQR

# Filter data to remove outliers
filtered_df = df[(df['balance'] >= lower_bound) & (df['balance'] <= upper_bound)]

# Display boxplot for 'balance' after removing outliers
sns.set(rc={'figure.figsize': (15, 10)})
sns.boxplot(data=filtered_df, x='education', y='balance')
plt.title('Boxplot of Balance by Education (Outliers Removed)')
plt.show()

# %%
# Glance - Check visually
sns.set(rc={'figure.figsize': (15,10)})
sns.boxplot(data=filtered_df, x= 'education', y="balance");

# %%
# Glance - Check visually
sns.set(rc={'figure.figsize': (15,10)})
sns.boxplot(data=df, x= 'job', y="balance")
plt.title('Boxplot of Balance by Education');

# %%
# Glance - Check visually
sns.set(rc={'figure.figsize': (15,10)})
sns.boxplot(data=filtered_df, x= 'job', y="balance")
plt.title('Boxplot of Balance by Job (Outliers Removed)');

# %%
# Glance - Check visually
sns.set(rc={'figure.figsize': (15,10)})
sns.boxplot(data=df, x= 'job', y="age")
plt.title('Boxplot of Balance by Age');

# %%
# list of numerical variables
numerical_features = [feature for feature in df.columns if ((df[feature].dtypes != 'O') & (feature not in ['deposit']))]
print('Number of numerical variables: ', len(numerical_features))

# visualise the numerical variables
df[numerical_features].head()
# Out:
# Number of numerical variables:  7
#    age  balance  day  duration  campaign  pdays  previous
# 0   59     2343    5      1042         1     -1         0
# 1   56       45    5      1467         1     -1         0
# 2   41     1270    5      1389         1     -1         0
# 3   55     2476    5       579         1     -1         0
# 4   54      184    5       673         2     -1         0

# %%
## Checking for correlation
cor_mat= df[numerical_features].corr()
fig = plt.figure(figsize=(15,7))
sns.heatmap(cor_mat, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Outcomes:
#
#
# *   It does not seem that any features are heavily correlated to each other
# *   Retired clients may have a higher interest in deposits due to higher balances
